# %% [markdown]
# # Notebook para corrigir os erros apresentados ao tentar enviar atualizações para o GitHub
#
# Este notebook ajuda a identificar o estado do repositório Git e resolver o problema de push, incluindo a remoção de refs quebrados ou arquivos indesejados como `desktop.ini`.

# %%
from pathlib import Path

root = Path(r"g:/Meu Drive/escolas/escolas.worktrees/New")
print("Workspace root:", root)
print("Exists:", root.exists())
print("Git worktree file:", (root / ".git").exists())
